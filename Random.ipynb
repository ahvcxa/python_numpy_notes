# %%
import numpy as np

# %%
rng = np.random.default_rng()

# %%
print(rng.integers(low=1,high=100))
# Out:
# 88

# %%
print(rng.integers(low=1,high=100,size=(3,2)))
# Out:
# [[67  8]
#  [54  8]
#  [51 26]]

# %%
print(np.random.uniform()) # it return 0-1 scale
# Out:
# 0.6287187241816877

# %%
print(np.random.uniform(-1,1)) # Now  return -1 - +1 scale
# Out:
# -0.6525261227250891

# %%
fruits = np.array(["🍌","🍉","🍏","🍍"])
rng.shuffle(fruits)
print(fruits)
# Out:
# ['🍉' '🍏' '🍌' '🍍']

# %%
fruits = np.array(["🍌","🍉","🍏","🍍"])
fruits = rng.choice(fruits,size=3)
print(fruits)
# Out:
# ['🍍' '🍍' '🍏']

# %%
fruits = np.array(["🍌","🍉","🍏","🍍"])
fruits = rng.choice(fruits,size=(3,3))
print(fruits)
# Out:
# [['🍏' '🍍' '🍌']
#  ['🍍' '🍌' '🍌']
#  ['🍉' '🍏' '🍉']]
