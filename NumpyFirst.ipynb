# %%
import numpy as np

# %%
print(np.__version__)
# Out:
# 2.2.2

# %%
array = np.array([1,2,3,4]) # with numpy
array = array*2
print(array)
# Out:
# [2 4 6 8]

# %%
my_list = [1,2,3,4] # with python
my_list = my_list * 2
print(my_list)
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]
