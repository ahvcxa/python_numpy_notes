# %%
import numpy as np

# %%
ages = np.array([15,17,56,34,23,12,67,36])

# %%
teenagers = ages [ages < 18]
print(teenagers)
# Out:
# [15 17 12]

# %%
adults = np.where(ages >= 18,ages,'-')
print(adults)
# Out:
# ['-' '-' '56' '34' '23' '-' '67' '36']
